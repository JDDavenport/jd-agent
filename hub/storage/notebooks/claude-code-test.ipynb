# %% [markdown]
# # Claude Code from Jupyter
#
# Testing Claude Code CLI integration.

# %%
# Test 1: Simple question
# !claude "What is 2 + 2? Reply with just the number." -p

# %%
# Test 2: Code explanation
code = '''
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quicksort(left) + middle + quicksort(right)
'''
print("Code to explain:")
print(code)

# %%
# Ask Claude to explain the code
# !claude "Explain this quicksort implementation in 2 sentences" -p

# %%
# Test 3: Generate code
# !claude "Write a Python one-liner to reverse a string. Just the code, no explanation." -p
