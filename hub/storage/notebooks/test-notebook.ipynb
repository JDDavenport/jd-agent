# %% [markdown]
# # Test Notebook
#
# This is a test notebook for the JD Agent Jupyter integration.

# %%
import pandas as pd
import numpy as np

# Create sample data
df = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [25, 30, 35],
    'score': [85, 92, 78]
})

print(df)

# %% [markdown]
# ## Analysis
#
# Let's analyze the data above.

# %%
# Calculate statistics
print(f"Mean age: {df['age'].mean()}")
print(f"Mean score: {df['score'].mean()}")
